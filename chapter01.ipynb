# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="env/.env")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

model = ChatOpenAI(model="gpt-4.1-nano")
model.invoke("The sky is")
# Out:
# AIMessage(content="The sky is often seen as blue during the day due due to the scattering of sunlight by Earth's atmosphere. At sunrise and sunset, it can display a variety of colors such as red, orange, and pink. The sky can also be clear or cloudy, depending on weather conditions, and it plays a vital role in Earth's climate and weather systems.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 10, 'total_tokens': 79, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_7ef751516d', 'id': 'chatcmpl-DQw241szVDfjJ6EobbsSS99010TCr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d58d6-f4d6-78d1-a248-a0412af19b9e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 69, 'total_tokens': 79, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
